# %%
from ultralytics import YOLO

# %%
from ultralytics import settings

# %%
# View all settings
print(settings)

# Return a specific setting
value = settings["runs_dir"]
# Out:
# JSONDict("/home/adam/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/media/Data/uav-1/datasets",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "69bf07fc4bd53bf7a767551eceba62d34c2dd8d25f660188c66c5a1d8dedc4d9",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": false,
#   "wandb": false,
#   "vscode_msg": true,
#   "openvino_msg": true
# }

# %%
# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo11n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 1.9MB/s 2.8s.8s<0.0ss3ss3s

# %%
# Create a new YOLO model from scratch
model = YOLO("yolo11n.yaml")



# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="coco8.yaml", epochs=3)

# Evaluate the model's performance on the validation set
results = model.val()

# Perform object detection on an image using the model
results = model("https://ultralytics.com/images/bus.jpg")

# Export the model to ONNX format
success = model.export(format="onnx")
