# %%
from ultralytics import YOLO
import os

# %%
yaml_content = """
train: visdrone/car/images/train
val: visdrone/car/images/val
test: visdrone/car/images/test

nc: 1  # nombre de classes
names: ['car']
"""
with open("visdrone_car.yaml", "w") as f:
    f.write(yaml_content)

# %%
model = YOLO("yolo11n.pt")

# %%
model.train(
    data="visdrone_car.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    name="visdrone_car_detection",
    cache=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.225 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221 🚀 Python-3.12.3 torch-2.9.0+cu128 CPU (13th Gen Intel Core i9-13900H)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=visdrone_car.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=visdrone_car_detection9, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/media/Data/uav-1/runs/detect/visdrone_car_detection9, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.2±0.1 ms, read: 109.2±36.0 MB/s, size: 182.1 KB)
# train: Scanning /media/Data/uav-1/visdrone/car/labels/train.cache... 6168 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6168/6168 4.4Mit/s 0.0s0s
# train: /media/Data/uav-1/visdrone/car/images/train/0000140_00118_d_0000002.jpg: 1 duplicate labels removed
# train: /media/Data/uav-1/visdrone/car/images/train/9999972_00000_d_0000158.jpg: 1 duplicate labels removed
# train: /media/Data/uav-1/visdrone/car/images/train/9999981_00000_d_0000047.jpg: 1 duplicate labels removed
# val: Fast image access ✅ (ping: 0.1±0.0 ms, read: 144.7±25.9 MB/s, size: 147.3 KB)
# val: Scanning /media/Data/uav-1/visdrone/car/labels/val.cache... 517 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 517/517 384.3Kit/s 0.0s
# Plotting labels to /media/Data/uav-1/runs/detect/visdrone_car_detection9/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /media/Data/uav-1/runs/detect/visdrone_car_detection9
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      1.556      1.426      0.996        411        640: 100% ━━━━━━━━━━━━ 386/386 0.1it/s 52:34<6.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.2it/s 1:305.5sss
#                    all        517      16039      0.724      0.531      0.591      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      1.479      1.017     0.9749        420        640: 100% ━━━━━━━━━━━━ 386/386 0.1it/s 52:53<6.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.2it/s 1:164.6sss
#                    all        517      16039      0.729      0.549      0.623      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G       1.46     0.9635     0.9664        316        640: 100% ━━━━━━━━━━━━ 386/386 0.0it/s 3:35:04<6.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.3it/s 1:064.0s4s
#                    all        517      16039      0.748       0.56      0.644      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      1.412       0.91     0.9585        633        640: 100% ━━━━━━━━━━━━ 386/386 0.1it/s 52:41<6.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.3it/s 1:053.8s1s
#                    all        517      16039      0.776      0.598      0.675      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G      1.393     0.8853      0.951        346        640: 100% ━━━━━━━━━━━━ 386/386 0.1it/s 52:43<6.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.3it/s 1:013.8sss
#                    all        517      16039      0.793      0.587      0.681      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G      1.378     0.8661     0.9459        321        640: 100% ━━━━━━━━━━━━ 386/386 0.1it/s 52:33<6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.3it/s 1:023.6sss
#                    all        517      16039      0.803       0.59      0.685      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G      1.344     0.8341     0.9387        402        640: 100% ━━━━━━━━━━━━ 386/386 0.1it/s 53:55<6.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.3it/s 1:053.9s3s
#                    all        517      16039      0.787      0.584      0.664      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G      1.327     0.8206     0.9348        330        640: 100% ━━━━━━━━━━━━ 386/386 0.1it/s 1:25:12<6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.3it/s 1:00<3.5ss
#                    all        517      16039      0.817      0.613      0.711      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G      1.314     0.8106     0.9334        284        640: 100% ━━━━━━━━━━━━ 386/386 0.1it/s 55:43<6.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.3it/s 1:023.7sss
#                    all        517      16039      0.792      0.598       0.69      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G      1.312     0.8027      0.928        316        640: 100% ━━━━━━━━━━━━ 386/386 0.2it/s 37:13<2.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.7it/s 24.6s1.5ss
#                    all        517      16039      0.815      0.614      0.706      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G      1.307      0.795      0.928        299        640: 100% ━━━━━━━━━━━━ 386/386 0.3it/s 21:07<2.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.7it/s 24.7s1.5ss
#                    all        517      16039      0.809      0.636      0.722      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0G       1.29     0.7772     0.9245        391        640: 100% ━━━━━━━━━━━━ 386/386 0.3it/s 21:52<2.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.7it/s 25.2s1.5ss
#                    all        517      16039      0.814      0.634      0.725      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         0G      1.278     0.7672     0.9199        542        640: 100% ━━━━━━━━━━━━ 386/386 0.3it/s 22:20<2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.7it/s 24.8s1.5ss
#                    all        517      16039      0.819      0.635       0.73      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         0G      1.271      0.755      0.917        430        640: 100% ━━━━━━━━━━━━ 386/386 0.3it/s 22:02<2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.7it/s 25.4s1.5ss
#                    all        517      16039      0.835      0.641      0.736      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         0G      1.267     0.7561     0.9169        524        640: 100% ━━━━━━━━━━━━ 386/386 0.3it/s 21:58<2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 0.7it/s 24.7s1.4ss
#                    all        517      16039      0.829      0.638      0.731      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         0G      1.241     0.7503     0.9196        644        640: 9% ━─────────── 35/386 0.3it/s 2:01<20:176

# %%
from ultralytics import YOLO
model = YOLO('/media/Data/uav-1/runs/detect/visdrone_car_detection9/weights/last.pt')
model.train(data="visdrone_car.yaml", epochs=50, imgsz=640, batch=16, name="visdrone_car_detection9", resume=True,cache=True)
