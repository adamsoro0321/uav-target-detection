# %%
from ultralytics import YOLO
import torch
import gc
import os

# Solution pour la fragmentation mémoire
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

# Nettoyage mémoire agressif
torch.cuda.empty_cache()
gc.collect()

# Load model
model = YOLO("yolo11n.pt")

DATA_YAML = "VisDrone.yaml"
RUN_NAME = "visdrone_detection_fast"

train_kwargs = dict(
    data=DATA_YAML,
    epochs=50,
    imgsz=640,
    batch=16,           # RÉDUIT à 8 (au lieu de 16)
    cache="ram",       # "ram" si assez de RAM, sinon "disk" ou False
    device=0,
    workers=4,         # RÉDUIT workers pour moins de mémoire
    resume=False,
    save_period=5,     # Réduit la fréquence des sauvegardes
    half=True,
    compile=False,     # DÉSACTIVE compile (peut causer OOM)
    patience=10,       # Arrêt précoce si pas d'amélioration
    lr0=0.01,          # Learning rate plus bas
    warmup_epochs=2,   # Warmup pour stabiliser
    close_mosaic=10,   # Désactive mosaic à la fin
)
# Train the model
results = model.train(**train_kwargs)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 3.3MB/s 1.6s.5s<0.1s1.9s0s
# New https://pypi.org/project/ultralytics/8.3.229 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221 🚀 Python-3.12.3 torch-2.9.0+cu128 CUDA:0 (NVIDIA RTX A1000 6GB Laptop GPU, 5807MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=ram, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=VisDrone.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=True, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/media/Data/uav/uav-target-detection/uav_1/runs/detect/train, save_frames=False, save_json=False, save_period=5, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=2, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    432622  ultralytics.nn.modules.head.Detect           [10, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,591,790 parameters, 2,591,774 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.1±0.0 ms, read: 338.0±91.7 MB/s, size: 260.7 KB)
# train: Scanning /media/Data/uav/uav-target-detection/uav_1/dataset/visdrone/labels/train.cache... 6471 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6471/6471 6.4Mit/s 0.0s0s
# train: /media/Data/uav/uav-target-detection/uav_1/dataset/visdrone/images/train/0000137_02220_d_0000163.jpg: 1 duplicate labels removed
# train: /media/Data/uav/uav-target-detection/uav_1/dataset/visdrone/images/train/0000140_00118_d_0000002.jpg: 1 duplicate labels removed
# train: /media/Data/uav/uav-target-detection/uav_1/dataset/visdrone/images/train/9999945_00000_d_0000114.jpg: 1 duplicate labels removed
# train: /media/Data/uav/uav-target-detection/uav_1/dataset/visdrone/images/train/9999987_00000_d_0000049.jpg: 1 duplicate labels removed
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (4.9GB RAM): 100% ━━━━━━━━━━━━ 6471/6471 320.7it/s 20.2s<0.0s
# val: Fast image access ✅ (ping: 0.2±0.2 ms, read: 136.5±85.5 MB/s, size: 143.9 KB)
# val: Scanning /media/Data/uav/uav-target-detection/uav_1/dataset/visdrone/labels/val.cache... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 396.6Kit/s 0.0s
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.4GB RAM): 100% ━━━━━━━━━━━━ 548/548 361.8it/s 1.5s0.1s
# Plotting labels to /media/Data/uav/uav-target-detection/uav_1/runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /media/Data/uav/uav-target-detection/uav_1/runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      4.55G      1.824      2.392      1.036        575        640: 100% ━━━━━━━━━━━━ 405/405 2.9it/s 2:18<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 1.2it/s 14.5s.3s
#                    all        548      38759      0.254      0.173      0.121     0.0617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      4.86G      1.678      1.527     0.9928        365        640: 100% ━━━━━━━━━━━━ 405/405 3.8it/s 1:45<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.246      0.209      0.174     0.0944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      4.96G      1.637      1.413     0.9804        393        640: 100% ━━━━━━━━━━━━ 405/405 3.9it/s 1:45<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.1s0.3s
#                    all        548      38759       0.27      0.226      0.196      0.111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      4.78G      1.614      1.352     0.9755        481        640: 100% ━━━━━━━━━━━━ 405/405 3.9it/s 1:45<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s0.3s
#                    all        548      38759      0.298      0.238      0.216       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         5G       1.58        1.3     0.9672        556        640: 100% ━━━━━━━━━━━━ 405/405 3.9it/s 1:45<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s0.2s
#                    all        548      38759      0.315      0.236      0.222      0.127
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      5.46G      1.562      1.262     0.9633        465        640: 100% ━━━━━━━━━━━━ 405/405 3.8it/s 1:46<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s0.2s
#                    all        548      38759      0.324      0.257      0.232      0.131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      4.25G      1.549      1.234     0.9594        574        640: 100% ━━━━━━━━━━━━ 405/405 3.9it/s 1:44<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s0.2s
#                    all        548      38759       0.31      0.276      0.242      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      4.48G      1.538      1.214     0.9545        773        640: 100% ━━━━━━━━━━━━ 405/405 3.9it/s 1:44<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s0.2s
#                    all        548      38759      0.336      0.267      0.242      0.135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      4.92G      1.525      1.198     0.9522        675        640: 100% ━━━━━━━━━━━━ 405/405 3.9it/s 1:44<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s0.2s
#                    all        548      38759      0.338      0.272      0.243      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      5.29G      1.521      1.179     0.9511        694        640: 100% ━━━━━━━━━━━━ 405/405 3.9it/s 1:45<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.2it/s 4.3s0.2s
#                    all        548      38759      0.346      0.268      0.252      0.143
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      3.75G      1.509       1.17     0.9479        308        640: 100% ━━━━━━━━━━━━ 405/405 3.9it/s 1:44<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s0.2s
#                    all        548      38759      0.352      0.276      0.256      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      5.36G      1.493      1.147     0.9449        653        640: 100% ━━━━━━━━━━━━ 405/405 3.9it/s 1:45<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.1it/s 4.4s0.2s
#                    all        548      38759      0.363      0.278      0.263      0.151
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      3.92G      1.484      1.136     0.9429        479        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:48<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.0it/s 4.5s0.2s
#                    all        548      38759      0.348      0.284      0.267      0.152
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      3.82G      1.482      1.134     0.9406        619        640: 100% ━━━━━━━━━━━━ 405/405 3.8it/s 1:47<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s0.3s
#                    all        548      38759      0.366      0.284      0.263      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      4.88G      1.474      1.123     0.9404        447        640: 100% ━━━━━━━━━━━━ 405/405 3.8it/s 1:47<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s0.3s
#                    all        548      38759      0.358      0.292      0.272      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      3.99G      1.469      1.117     0.9392       1029        640: 100% ━━━━━━━━━━━━ 405/405 3.8it/s 1:48<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.2s0.3s
#                    all        548      38759      0.371      0.292       0.28      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      4.74G       1.46      1.101     0.9362        598        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:48<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.4it/s 5.3s0.3s
#                    all        548      38759      0.381        0.3      0.286      0.164
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      4.74G      1.457      1.096     0.9366       1011        640: 100% ━━━━━━━━━━━━ 405/405 3.8it/s 1:48<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.2s
#                    all        548      38759      0.383      0.296       0.28       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      4.94G      1.451      1.089     0.9335        434        640: 100% ━━━━━━━━━━━━ 405/405 3.6it/s 1:52<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.2s0.3s
#                    all        548      38759      0.368      0.293      0.276      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      4.05G      1.441       1.08     0.9323        555        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:49<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.376      0.301      0.286      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      4.51G      1.442      1.071     0.9305        563        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:49<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s0.2s
#                    all        548      38759      0.398      0.296      0.289      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      4.37G      1.444      1.073     0.9318        558        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:50<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s0.3s
#                    all        548      38759      0.383      0.298      0.284      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      5.35G      1.439       1.07     0.9312        478        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:50<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 4.9s0.3s
#                    all        548      38759      0.399        0.3      0.296      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      3.91G      1.432       1.06     0.9291        704        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:49<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.1s0.3s
#                    all        548      38759      0.398      0.306      0.298      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      4.98G      1.423      1.046     0.9273        481        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:50<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.7s0.2s
#                    all        548      38759      0.392      0.302      0.294      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      4.02G      1.412      1.041     0.9262        527        640: 100% ━━━━━━━━━━━━ 405/405 3.8it/s 1:47<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.2s
#                    all        548      38759      0.404      0.299      0.297      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      4.35G       1.42      1.041     0.9237        805        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:49<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s0.2s
#                    all        548      38759      0.397      0.311      0.301      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      4.09G      1.418      1.038     0.9246        530        640: 100% ━━━━━━━━━━━━ 405/405 3.8it/s 1:47<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s0.3s
#                    all        548      38759      0.386      0.316      0.301      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      4.66G       1.41      1.031     0.9235        699        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:48<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s0.2s
#                    all        548      38759      0.404      0.307      0.301      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      4.57G      1.409      1.031     0.9236        618        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:51<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.2s0.3s
#                    all        548      38759      0.403      0.314      0.301      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50       3.9G      1.401      1.019     0.9209        525        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:51<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.4it/s 5.3s0.3s
#                    all        548      38759      0.404      0.312      0.302      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50       4.4G      1.391      1.013     0.9189        623        640: 100% ━━━━━━━━━━━━ 405/405 3.6it/s 1:54<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.2it/s 5.6s0.3s
#                    all        548      38759      0.402      0.317      0.304      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      4.49G      1.389       1.01     0.9188        581        640: 100% ━━━━━━━━━━━━ 405/405 3.5it/s 1:55<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.1it/s 5.7s0.3s
#                    all        548      38759      0.395      0.316      0.306      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      3.97G      1.382      1.001     0.9174       1358        640: 38% ━━━━╸─────── 155/405 3.6it/s 44.1s<1:10WARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       34/50      4.86G      1.389      1.005     0.9188        426        640: 100% ━━━━━━━━━━━━ 405/405 2.9it/s 2:19<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s0.3s
#                    all        548      38759      0.418       0.32      0.313       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      5.15G       1.39     0.9987     0.9175        519        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:48<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.4it/s 5.3s0.3s
#                    all        548      38759      0.407      0.314      0.307      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      5.26G      1.386     0.9988     0.9174        650        640: 100% ━━━━━━━━━━━━ 405/405 3.6it/s 1:53<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.406      0.324      0.311       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      3.62G      1.377     0.9955     0.9188       1196        640: 15% ━╸────────── 62/405 3.7it/s 16.9s<1:34WARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       37/50      4.76G      1.381     0.9938     0.9167        727        640: 100% ━━━━━━━━━━━━ 405/405 3.1it/s 2:10<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.413      0.321      0.312       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      4.47G      1.374     0.9855     0.9154        518        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:50<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.1s0.3s
#                    all        548      38759      0.411      0.321      0.315      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      4.82G      1.367     0.9761     0.9128        708        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:49<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s0.3s
#                    all        548      38759      0.408      0.319      0.311      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      3.94G      1.371     0.9819     0.9138        931        640: 100% ━━━━━━━━━━━━ 405/405 3.7it/s 1:48<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.2s
#                    all        548      38759      0.409      0.322      0.312      0.181
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50       4.8G      1.345     0.9626     0.9146        165        640: 100% ━━━━━━━━━━━━ 405/405 4.0it/s 1:41<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.407      0.324      0.311       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      5.39G      1.331     0.9442     0.9122        261        640: 100% ━━━━━━━━━━━━ 405/405 4.1it/s 1:38<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s0.3s
#                    all        548      38759      0.412      0.318       0.31      0.179
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50       4.8G      1.324     0.9384     0.9114        250        640: 100% ━━━━━━━━━━━━ 405/405 4.1it/s 1:39<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759       0.42      0.314      0.311       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      3.95G      1.324     0.9352     0.9093        554        640: 100% ━━━━━━━━━━━━ 405/405 4.0it/s 1:40<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 4.9s0.3s
#                    all        548      38759      0.408      0.317      0.309      0.179
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.27G      1.318     0.9269     0.9082        366        640: 100% ━━━━━━━━━━━━ 405/405 4.0it/s 1:40<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.1s0.3s
#                    all        548      38759      0.404      0.322      0.311       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.39G      1.314     0.9196     0.9061        226        640: 100% ━━━━━━━━━━━━ 405/405 4.1it/s 1:39<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.1s0.3s
#                    all        548      38759      0.407      0.317       0.31       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.43G      1.304      0.913     0.9059        308        640: 100% ━━━━━━━━━━━━ 405/405 4.1it/s 1:39<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 4.9s0.3s
#                    all        548      38759      0.404      0.321      0.313      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      3.74G      1.305     0.9116     0.9048        323        640: 100% ━━━━━━━━━━━━ 405/405 4.1it/s 1:39<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.404      0.325      0.314      0.181
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 38, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 48 epochs completed in 1.528 hours.
# Optimizer stripped from /media/Data/uav/uav-target-detection/uav_1/runs/detect/train/weights/last.pt, 5.5MB
# Optimizer stripped from /media/Data/uav/uav-target-detection/uav_1/runs/detect/train/weights/best.pt, 5.5MB
#
# Validating /media/Data/uav/uav-target-detection/uav_1/runs/detect/train/weights/best.pt...
# Ultralytics 8.3.221 🚀 Python-3.12.3 torch-2.9.0+cu128 CUDA:0 (NVIDIA RTX A1000 6GB Laptop GPU, 5807MiB)
# YOLO11n summary (fused): 100 layers, 2,584,102 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 1.5it/s 12.3s0.3s
#                    all        548      38759       0.41      0.322      0.315      0.182
#             pedestrian        520       8844      0.398      0.334      0.322      0.137
#                 people        482       5125      0.476       0.21      0.246     0.0861
#                bicycle        364       1287      0.201      0.103      0.074     0.0266
#                    car        515      14064      0.599      0.735      0.734      0.499
#                    van        421       1975      0.456       0.35      0.357      0.243
#                  truck        266        750      0.421      0.325      0.308      0.199
#               tricycle        337       1045      0.348      0.229      0.197      0.112
#        awning-tricycle        220        532      0.214      0.145      0.103     0.0667
#                    bus        131        251      0.549      0.438      0.476      0.318
#                  motor        485       4886       0.44      0.353      0.334      0.134
# Speed: 0.2ms preprocess, 1.6ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to /media/Data/uav/uav-target-detection/uav_1/runs/detect/train

# %%
MODEL_PRETRAINED = YOLO("/media/Data/uav/uav-target-detection/uav_1/runs/detect/train/weights/best.pt")

# %%
# Évaluation sur le dataset de validation
results = model.val(data='VisDrone.yaml', split='val')
# Out:
# Ultralytics 8.3.221 🚀 Python-3.12.3 torch-2.9.0+cu128 CUDA:0 (NVIDIA RTX A1000 6GB Laptop GPU, 5807MiB)
# val: Fast image access ✅ (ping: 0.1±0.0 ms, read: 182.2±60.8 MB/s, size: 110.2 KB)
# val: Scanning /media/Data/uav/uav-target-detection/uav_1/dataset/visdrone/labels/val.cache... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 332.3Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 3.7it/s 9.4s0.1s
#                    all        548      38759     0.0354      0.136     0.0312     0.0144
#                 person        520       8844     0.0909      0.281      0.145     0.0625
#                bicycle        482       5125      0.101      0.066     0.0554     0.0183
#                    car        364       1287    0.00247      0.109    0.00139   0.000404
#             motorcycle        515      14064      0.052     0.0235     0.0266     0.0175
#               airplane        421       1975     0.0187    0.00152    0.00944    0.00692
#                    bus        266        750     0.0248      0.336     0.0334     0.0206
#                  train        337       1045    0.00769     0.0115     0.0039    0.00227
#                  truck        220        532    0.00803      0.432       0.01    0.00538
#                   boat        131        251    0.00489     0.0398    0.00264    0.00198
#          traffic light        485       4886     0.0436       0.06     0.0239    0.00786
# Speed: 0.7ms preprocess, 3.8ms inference, 0.0ms loss, 7.7ms postprocess per image
# Results saved to /media/Data/uav/uav-target-detection/uav_1/runs/detect/val2
